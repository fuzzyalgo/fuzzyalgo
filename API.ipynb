# %%
import algotrader as at

# %%
gH = at.Algotrader('RF5D03')
gH.mt5_init()
gH.set_gc0()
# Out:
# EURUSD 1.03056 set new base line - start point - gc0 price

# %%
gH.mt5_cnt_orders_and_positions( 'EURUSD' )
# Out:
# ({'total': 0,
#   'order_pend_buy': 0,
#   'order_pend_buy_vol': 0.0,
#   'order_pend_buy_price': 0.0,
#   'order_pend_buy_time_msc': 0,
#   'order_pend_buy_ticket': 0,
#   'order_pend_sell': 0,
#   'order_pend_sell_vol': 0.0,
#   'order_pend_sell_price': 0.0,
#   'order_pend_sell_time_msc': 0,
#   'order_pend_sell_ticket': 0,
#   'order_pos_buy': 0,
#   'order_pos_buy_vol': 0.0,
#   'order_pos_buy_price0': 0.0,
#   'order_pos_buy_price_min': 1000000.0,
#   'order_pos_buy_price_max': 0.0,
#   'order_pos_buy_profit': 0,
#   'order_pos_buy_profitm': 0.0,
#   'order_pos_buy_time': 0,
#   'order_pos_buy_ticket': 0,
#   'order_pos_buy_magic': 0,
#   'order_pos_buy_sl': 0,
#   'order_pos_buy_tp': 0,
#   'order_pos_sell': 0,
#   'order_pos_sell_vol': 0.0,
#   'order_pos_sell_price0': 0.0,
#   'order_pos_sell_price_min': 1000000.0,
#   'order_pos_sell_price_max': 0.0,
#   'order_pos_sell_profit': 0,
#   'order_pos_sell_profitm': 0.0,
#   'order_pos_sell_time': 0,
#   'order_pos_sell_ticket': 0,
#   'order_pos_sell_magic': 0,
#   'order_pos_sell_sl': 0,
#   'order_pos_sell_tp': 0},
#             cnt  profit  sl  tp  delta    price           time  ticket
#  POS_BUY      0       0   0   0      0  0.00000              0       0
#  PEND_BUY     0       0   0   0      0  0.00000              0       0
#  c0           1       0   0   0      0  1.03056  1736122855473       0
#  PEND_SELL    0       0   0   0      0  0.00000              0       0
#  POS_SELL     0       0   0   0      0  0.00000              0       0)

# %%
# global time vars
gTimezoneUTC = timezone.utc
gTdOffset= timedelta(hours=2)   # TODO recognise me - summer time 3h and winter time 2h
gTicksPerPeriod = 36#36000  #  10hours * 36000secs/hours -> 36000 ticks per period
gTimeDelta = timedelta( hours=4 )   # TODO config var 10 hours -> related to 36000 (gTicksPerPeriod) elements for ticks array
#gDtTo   = datetime.now(gTimezoneUTC) + gTdOffset
gDtTo   = datetime(2025, 1, 3, 17, 2, 50, 0, tzinfo=gTimezoneUTC)
gDtFrom = gDtTo - gTimeDelta
print( "\nFrom: ", gDtFrom, " To: ", gDtTo )
gDtTo_epoch_ms = int(gDtTo.timestamp()*1000)
print( "\ngDtTo.timestamp() ", gDtTo.timestamp(), " gDtTo_epoch_ms: ", gDtTo_epoch_ms)
# Out:
# From:  2025-01-03 13:02:50+00:00  To:  2025-01-03 17:02:50+00:00
#
# gDtTo.timestamp()  1735923770.0  gDtTo_epoch_ms:  1735923770000

# %%
# analyse a singe data frame
gH.get_date_range(gDtTo)
gH.get_ticks_and_rates( 'EURUSD' )
gH.analyse_df( 'EURUSD' )
gH.run_analyse( gDtTo, 'EURUSD' )
# Out:
#         sec     vol   cnt             t1             t0          dt_to  \
# T1      0.0     1.0  10.0  1735923764271  1735923769869  1735923770000
# T5      0.0     5.0  10.0  1735923747086  1735923767053  1735923770000
# T15     0.0    15.0  10.0  1735923724782  1735923762382  1735923770000
# T30     0.0    30.0  10.0  1735923685199  1735923755182  1735923770000
# T60     0.0    60.0  10.0  1735923620046  1735923745262  1735923770000
# T300    0.0   300.0  10.0  1735922266573  1735923685199  1735923770000
# T900    0.0   900.0  10.0  1735918502775  1735923555438  1735923770000
# T3600   0.0  3600.0  10.0  1735898546946  1735921933325  1735923770000
# SUMROW  0.0   613.0  10.0  1735919732209  1735923496713  1735923770000
#
#               c1       c0  DELTA   OC   HL     TD   VOLS   TT  HL/TD  HL/VOLS  \
# T1      1.029740  1.02975    -80    0    2      5     10  500    0.4      0.2
# T5      1.029660  1.02975    -80    8   18     22     50  440    0.8      0.4
# T15     1.029540  1.02975    -80   21   36     45    150  300    0.8      0.2
# T30     1.029660  1.02975    -80    8   39     84    300  280    0.5      0.1
# T60     1.029510  1.02975    -80   24   95    149    600  248    0.6      0.2
# T300    1.029710  1.02975    -80    4  121   1503   3000  501    0.1      0.0
# T900    1.029970  1.02975    -80  -22  143   5267   9000  585    0.0      0.0
# T3600   1.027870  1.02975    -80  187  298  25223  36000  701    0.0      0.0
# SUMROW  1.029457  1.02975    -80   28   94   4037   6138  444    0.4      0.1
#
#         SUMCOL
# T1         0.6
# T5         1.2
# T15        1.0
# T30        0.6
# T60        0.8
# T300       0.1
# T900       0.0
# T3600      0.0
# SUMROW     0.5

# %%
# same as abaove
gH.run_analyse( gDtTo, 'EURUSD' )
# Out:
#         sec     vol   cnt             t1             t0          dt_to  \
# T1      0.0     1.0  10.0  1735923764271  1735923769869  1735923770000
# T5      0.0     5.0  10.0  1735923747086  1735923767053  1735923770000
# T15     0.0    15.0  10.0  1735923724782  1735923762382  1735923770000
# T30     0.0    30.0  10.0  1735923685199  1735923755182  1735923770000
# T60     0.0    60.0  10.0  1735923620046  1735923745262  1735923770000
# T300    0.0   300.0  10.0  1735922266573  1735923685199  1735923770000
# T900    0.0   900.0  10.0  1735918502775  1735923555438  1735923770000
# T3600   0.0  3600.0  10.0  1735898546946  1735921933325  1735923770000
# SUMROW  0.0   613.0  10.0  1735919732209  1735923496713  1735923770000
#
#               c1       c0  DELTA   OC   HL     TD   VOLS   TT  HL/TD  HL/VOLS  \
# T1      1.029740  1.02975    -80    0    2      5     10  500    0.4      0.2
# T5      1.029660  1.02975    -80    8   18     22     50  440    0.8      0.4
# T15     1.029540  1.02975    -80   21   36     45    150  300    0.8      0.2
# T30     1.029660  1.02975    -80    8   39     84    300  280    0.5      0.1
# T60     1.029510  1.02975    -80   24   95    149    600  248    0.6      0.2
# T300    1.029710  1.02975    -80    4  121   1503   3000  501    0.1      0.0
# T900    1.029970  1.02975    -80  -22  143   5267   9000  585    0.0      0.0
# T3600   1.027870  1.02975    -80  187  298  25223  36000  701    0.0      0.0
# SUMROW  1.029457  1.02975    -80   28   94   4037   6138  444    0.4      0.1
#
#         SUMCOL
# T1         0.6
# T5         1.2
# T15        1.0
# T30        0.6
# T60        0.8
# T300       0.1
# T900       0.0
# T3600      0.0
# SUMROW     0.5

# %%
# live  modus
#gH.set_gc0()

# analysis modus
df = gH.get_df_rates( gDtTo, 'T900', 'EURUSD' )
gH.g_c0['EURUSD'] = df.iloc[0].close
#gH.set_gc0_price( gSym, df.iloc[0].close )
print(df.iloc[0].close)
# Out:
# 1.02997

# %%
# same as above with different output
dfana = gH.run_analyse( gDtTo, 'EURUSD' )
gH.print_analyse_df( dfana )
# Out:
#         DELTA   OC   HL     TD   VOLS   TT  HL/TD  HL/VOLS  SUMCOL
# T1        -22    0    2      5     10  500    0.4      0.2     0.6
# T5        -22    8   18     22     50  440    0.8      0.4     1.2
# T15       -22   21   36     45    150  300    0.8      0.2     1.0
# T30       -22    8   39     84    300  280    0.5      0.1     0.6
# T60       -22   24   95    149    600  248    0.6      0.2     0.8
# T300      -22    4  121   1503   3000  501    0.1      0.0     0.1
# T900      -22  -22  143   5267   9000  585    0.0      0.0     0.0
# T3600     -22  187  298  25223  36000  701    0.0      0.0     0.0
# SUMROW    -22   28   94   4037   6138  444    0.4      0.1     0.5

# %%
gH.print_fig_all_periods_per_sym()

# %%
gH.run_now( gDtTo, 'EURUSD' )
# Out:
#         DELTA   OC   HL     TD   VOLS   TT  HL/TD  HL/VOLS  SUMCOL
# T1        -22    0    2      5     10  500    0.4      0.2     0.6
# T5        -22    8   18     22     50  440    0.8      0.4     1.2
# T15       -22   21   36     45    150  300    0.8      0.2     1.0
# T30       -22    8   39     84    300  280    0.5      0.1     0.6
# T60       -22   24   95    149    600  248    0.6      0.2     0.8
# T300      -22    4  121   1503   3000  501    0.1      0.0     0.1
# T900      -22  -22  143   5267   9000  585    0.0      0.0     0.0
# T3600     -22  187  298  25223  36000  701    0.0      0.0     0.0
# SUMROW    -22   28   94   4037   6138  444    0.4      0.1     0.5
