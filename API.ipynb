# %%
import algotrader as at

# %%
gH = at.Algotrader('RF5D03')
gH.mt5_init()
gH.set_gc0()
# Out:
# EURUSD 1.05125 set new base line - start point - gc0 price

# %%
gH.mt5_cnt_orders_and_positions( 'EURUSD' )
# Out:
# ({'total': 0,
#   'order_pend_buy': 0,
#   'order_pend_buy_vol': 0.0,
#   'order_pend_buy_price': 0.0,
#   'order_pend_buy_time_msc': 0,
#   'order_pend_buy_ticket': 0,
#   'order_pend_sell': 0,
#   'order_pend_sell_vol': 0.0,
#   'order_pend_sell_price': 0.0,
#   'order_pend_sell_time_msc': 0,
#   'order_pend_sell_ticket': 0,
#   'order_pos_buy': 0,
#   'order_pos_buy_vol': 0.0,
#   'order_pos_buy_price0': 0.0,
#   'order_pos_buy_price_min': 1000000.0,
#   'order_pos_buy_price_max': 0.0,
#   'order_pos_buy_profit': 0,
#   'order_pos_buy_profitm': 0.0,
#   'order_pos_buy_time': 0,
#   'order_pos_buy_ticket': 0,
#   'order_pos_buy_magic': 0,
#   'order_pos_buy_sl': 0,
#   'order_pos_buy_tp': 0,
#   'order_pos_sell': 0,
#   'order_pos_sell_vol': 0.0,
#   'order_pos_sell_price0': 0.0,
#   'order_pos_sell_price_min': 1000000.0,
#   'order_pos_sell_price_max': 0.0,
#   'order_pos_sell_profit': 0,
#   'order_pos_sell_profitm': 0.0,
#   'order_pos_sell_time': 0,
#   'order_pos_sell_ticket': 0,
#   'order_pos_sell_magic': 0,
#   'order_pos_sell_sl': 0,
#   'order_pos_sell_tp': 0},
#             cnt  profit  sl  tp  delta    price           time  ticket
#  POS_BUY      0       0   0   0      0  0.00000              0       0
#  PEND_BUY     0       0   0   0      0  0.00000              0       0
#  c0           1       0   0   0      0  1.05125  1673009646753       0
#  PEND_SELL    0       0   0   0      0  0.00000              0       0
#  POS_SELL     0       0   0   0      0  0.00000              0       0)

# %%
# first get the time gDtFrom
from datetime import datetime
from datetime import timezone
from datetime import timedelta
gTimezoneUTC=timezone.utc #pytz.timezone('Etc/UTC')
gTdOffset= timedelta(hours=2)   # TODO recognise me - summer time 3h and winter time 2h
gDtFrom = datetime.now(gTimezoneUTC) + gTdOffset
#gDtFrom = datetime(2022,12,23,10,00,20,tzinfo=gTimezoneUTC)
#gDtFrom = None
print( gDtFrom )
# Out:
# 2023-01-06 12:54:10.159105+00:00

# %%
# analyse a singe data frame
gH.get_date_range(gDtFrom)
gH.get_ticks_and_rates( 'EURUSD' )
gH.analyse_df( 'EURUSD' )
#gH.run_analyse( gDtFrom, 'EURUSD' )
# Out:
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
#            sec     vol   cnt             t1             t0          dt_to  \
# T1         0.0     1.0  10.0  1673009638052  1673009648268  1673009650159
# T5         0.0     5.0  10.0  1673009612716  1673009645948  1673009650159
# T15        0.0    15.0  10.0  1673009556422  1673009633957  1673009650159
# T30        0.0    30.0  10.0  1673009477268  1673009624677  1673009650159
# T60        0.0    60.0  10.0  1673009278225  1673009607336  1673009650159
# T300       0.0   300.0  10.0  1673007890839  1673009477268  1673009650159
# T900       0.0   900.0  10.0  1673004946630  1673009095585  1673009650159
# T3600      0.0  3600.0  10.0  1672988516241  1673007516907  1673009650159
# M1        60.0     0.0  10.0  1673009050401  1673009590029  1673009650159
# M5       300.0     0.0  10.0  1673006650033  1673009350153  1673009650159
# M15      900.0     0.0  10.0  1673000650490  1673008752986  1673009650159
# H1      3600.0     0.0  10.0  1672973653278  1673006051487  1673009650159
# SUMROW   405.0   409.0  10.0  1673003243382  1673008999550  1673009650159
#
#               c1       c0  DELTA   OC   HL     TD   VOLS    TT  HL/TD  \
# T1      1.051240  1.05125      0    1    5     12     10  1200    0.4
# T5      1.051360  1.05125      0  -11   17     37     50   740    0.5
# T15     1.051180  1.05125      0    7   25     93    150   620    0.3
# T30     1.051250  1.05125      0    0   31    172    300   573    0.2
# T60     1.051310  1.05125      0   -5   34    371    600   618    0.1
# T300    1.050600  1.05125      0   65  130   1759   3000   586    0.1
# T900    1.050720  1.05125      0   52  130   4703   9000   523    0.0
# T3600   1.051890  1.05125      0  -63  344  21133  36000   587    0.0
# M1      1.051340  1.05125      0   -8   45    599    964   621    0.1
# M5      1.051340  1.05125      0   -8  130   3000   5489   547    0.0
# M15     1.052060  1.05125      0  -80  300   8999  17971   501    0.0
# H1      1.052540  1.05125      0 -129  399  35996  48209   747    0.0
# SUMROW  1.051403  1.05125      0  -14  132   6406  10145   655    0.1
#
#         HL/VOLS  SUMCOL
# T1          0.5     0.9
# T5          0.3     0.8
# T15         0.2     0.5
# T30         0.1     0.3
# T60         0.1     0.2
# T300        0.0     0.1
# T900        0.0     0.0
# T3600       0.0     0.0
# M1          0.0     0.1
# M5          0.0     0.0
# M15         0.0     0.0
# H1          0.0     0.0
# SUMROW      0.1     0.2

# %%
# same as abaove
gH.run_analyse( gDtFrom, 'EURUSD' )
# Out:
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
#            sec     vol   cnt             t1             t0          dt_to  \
# T1         0.0     1.0  10.0  1673009638052  1673009648268  1673009650159
# T5         0.0     5.0  10.0  1673009612716  1673009645948  1673009650159
# T15        0.0    15.0  10.0  1673009556422  1673009633957  1673009650159
# T30        0.0    30.0  10.0  1673009477268  1673009624677  1673009650159
# T60        0.0    60.0  10.0  1673009278225  1673009607336  1673009650159
# T300       0.0   300.0  10.0  1673007890839  1673009477268  1673009650159
# T900       0.0   900.0  10.0  1673004946630  1673009095585  1673009650159
# T3600      0.0  3600.0  10.0  1672988516241  1673007516907  1673009650159
# M1        60.0     0.0  10.0  1673009050401  1673009590029  1673009650159
# M5       300.0     0.0  10.0  1673006650033  1673009350153  1673009650159
# M15      900.0     0.0  10.0  1673000650490  1673008752986  1673009650159
# H1      3600.0     0.0  10.0  1672973653278  1673006051487  1673009650159
# SUMROW   405.0   409.0  10.0  1673003243382  1673008999550  1673009650159
#
#               c1       c0  DELTA   OC   HL     TD   VOLS    TT  HL/TD  \
# T1      1.051240  1.05125      0    1    5     12     10  1200    0.4
# T5      1.051360  1.05125      0  -11   17     37     50   740    0.5
# T15     1.051180  1.05125      0    7   25     93    150   620    0.3
# T30     1.051250  1.05125      0    0   31    172    300   573    0.2
# T60     1.051310  1.05125      0   -5   34    371    600   618    0.1
# T300    1.050600  1.05125      0   65  130   1759   3000   586    0.1
# T900    1.050720  1.05125      0   52  130   4703   9000   523    0.0
# T3600   1.051890  1.05125      0  -63  344  21133  36000   587    0.0
# M1      1.051340  1.05125      0   -8   45    599    964   621    0.1
# M5      1.051340  1.05125      0   -8  130   3000   5489   547    0.0
# M15     1.052060  1.05125      0  -80  300   8999  17971   501    0.0
# H1      1.052540  1.05125      0 -129  399  35996  48209   747    0.0
# SUMROW  1.051403  1.05125      0  -14  132   6406  10145   655    0.1
#
#         HL/VOLS  SUMCOL
# T1          0.5     0.9
# T5          0.3     0.8
# T15         0.2     0.5
# T30         0.1     0.3
# T60         0.1     0.2
# T300        0.0     0.1
# T900        0.0     0.0
# T3600       0.0     0.0
# M1          0.0     0.1
# M5          0.0     0.0
# M15         0.0     0.0
# H1          0.0     0.0
# SUMROW      0.1     0.2

# %%
gH.set_gc0()
# Out:
# EURUSD 1.06189 set new base line - start point - gc0 price

# %%
# same as above with different output
dfana = gH.run_analyse( None, 'EURUSD' )
gH.print_analyse_df( dfana )
# Out:
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
#         DELTA   OC    HL     TD    VOLS   TT  HL/TD  HL/VOLS  SUMCOL
# T1          1    0     8      4      10  400    2.0      0.8     2.8
# T5          1  -17    25     30      50  600    0.8      0.5     1.3
# T15         1  -14    25     83     150  553    0.3      0.2     0.5
# T30         1   -8    25    178     300  593    0.1      0.1     0.2
# T60         1   12    39    358     600  597    0.1      0.1     0.2
# T300        1   -9    72   1450    3000  483    0.0      0.0     0.0
# T900        1   93   207   3237    9000  360    0.1      0.0     0.1
# T3600       1  436   767   8143   36000  226    0.1      0.0     0.1
# M1          1   -5    45    600     999  601    0.1      0.0     0.1
# M5          1   27   144   3000    8217  365    0.0      0.0     0.0
# M15         1  601  1175   9000   42780  210    0.1      0.0     0.1
# H1          1  929  1407  36000  121082  297    0.0      0.0     0.0
# SUMROW      1  170   328   5173   18515  440    0.3      0.1     0.4

# %%
gDtFrom = datetime.now(gTimezoneUTC) + gTdOffset
print( gDtFrom )
gH.print_fig_all_periods_per_sym()
# Out:
# 2023-01-06 19:23:08.713097+00:00

# %%
gH.run_now( None, 'EURUSD' )
# Out:
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
# C:\apps\anaconda3\envs\fuzzyalgo-py38\lib\site-packages\algotrader\algotrader.py:1293: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df = df.loc[strend:strstart]
#         DELTA    OC    HL     TD    VOLS   TT  HL/TD  HL/VOLS  SUMCOL
# T1        261     7     7      6      10  600    1.2      0.7     1.9
# T5        261    25    25     46      50  920    0.5      0.5     1.0
# T15       261    24    38    105     150  700    0.4      0.3     0.7
# T30       261    11    38    285     300  950    0.1      0.1     0.2
# T60       261   -15    68    432     600  720    0.2      0.1     0.3
# T300      261    69   117   1978    3000  659    0.1      0.0     0.1
# T900      261    76   201   5378    9000  598    0.0      0.0     0.0
# T3600     261   385   615  13576   36000  377    0.0      0.0     0.0
# M1        256    -8    69    600     906  662    0.1      0.1     0.2
# M5        256    63   158   3000    4586  654    0.1      0.0     0.1
# M15       256   214   329   8999   16710  539    0.0      0.0     0.0
# H1        256  1329  1649  36000  118593  304    0.0      0.0     0.0
# SUMROW    259   181   276   5867   15825  640    0.2      0.2     0.4
